# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# # Felippe Teracini
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %%
# Observar a relacao tv-internet ao longo dos 3 anos nas zonas rurais e urbanas das regioes brasileiras

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Felippe\Documents\Insper\Semestre 2\Ciencia dos Dados\Projeto 1\Projeto-1-CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
dados2015 = pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
# Divisão por regiões do Brasil
dados2015.loc[(dados2015.UF <= 17),"Região"] = "Norte"
dados2015.loc[(dados2015.UF > 17) | (dados2015.UF <= 29),"Região"] = "Nordeste"
dados2015.loc[(dados2015.UF > 29) | (dados2015.UF <= 35),"Região"] = "Sudeste"
dados2015.loc[(dados2015.UF > 35) | (dados2015.UF <= 43),"Região"] = "Sul"
dados2015.loc[(dados2015.UF > 43),"Região"] = "Centro-Oeste"

# Divisão por disponibilidade de internet no domicílio // !! Remover os NAN
dados2015.loc[(dados2015.V02322 == 2), "Internet"] = "Sim"
dados2015.loc[(dados2015.V02322 == 4), "Internet"] = "Não"
dados2015 = dados2015[pd.notnull(dados2015["V02322"])]

# Divisão por zona (Rural ou Urbana)
dados2015.loc[(dados2015.V4105 == 1), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 2), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 3), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 4), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 5), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 6), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 7), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 8), "Zona"] = "Rural"

#Tabela Final
dados2015.loc[:,["Região", "Zona", "Internet"]]
# Out:
#               Região    Zona Internet
# 0                Sul  Urbana      Não
# 2                Sul  Urbana      Sim
# 3                Sul  Urbana      Sim
# 4                Sul  Urbana      Não
# 5                Sul  Urbana      Sim
# 6                Sul  Urbana      Não
# 7                Sul  Urbana      Não
# 8                Sul  Urbana      Sim
# 10               Sul  Urbana      Sim
# 11               Sul  Urbana      Sim
# 13               Sul  Urbana      Sim
# 15               Sul  Urbana      Sim
# 16               Sul  Urbana      Não
# 17               Sul  Urbana      Sim
# 18               Sul  Urbana      Sim
# 19               Sul  Urbana      Sim
# 20               Sul  Urbana      Sim
# 21               Sul  Urbana      Não
# 23               Sul  Urbana      Sim
# 26               Sul  Urbana      Não
# 27               Sul  Urbana      Sim
# 28               Sul  Urbana      Sim
# 29               Sul  Urbana      Sim
# 30               Sul  Urbana      Não
# 31               Sul  Urbana      Sim
# 32               Sul  Urbana      Sim
# 33               Sul  Urbana      Sim
# 35               Sul  Urbana      Não
# 36               Sul  Urbana      Não
# 37               Sul  Urbana      Sim
# ...              ...     ...      ...
# 151147  Centro-Oeste  Urbana      Sim
# 151148  Centro-Oeste  Urbana      Sim
# 151150  Centro-Oeste  Urbana      Sim
# 151151  Centro-Oeste  Urbana      Sim
# 151153  Centro-Oeste  Urbana      Sim
# 151155  Centro-Oeste  Urbana      Não
# 151156  Centro-Oeste  Urbana      Sim
# 151158  Centro-Oeste  Urbana      Sim
# 151159  Centro-Oeste  Urbana      Sim
# 151161  Centro-Oeste  Urbana      Sim
# 151163  Centro-Oeste  Urbana      Sim
# 151164  Centro-Oeste  Urbana      Sim
# 151165  Centro-Oeste  Urbana      Sim
# 151167  Centro-Oeste  Urbana      Sim
# 151168  Centro-Oeste  Urbana      Sim
# 151169  Centro-Oeste  Urbana      Sim
# 151170  Centro-Oeste  Urbana      Sim
# 151171  Centro-Oeste  Urbana      Sim
# 151172  Centro-Oeste  Urbana      Não
# 151173  Centro-Oeste  Urbana      Sim
# 151175  Centro-Oeste  Urbana      Sim
# 151179  Centro-Oeste  Urbana      Não
# 151180  Centro-Oeste  Urbana      Não
# 151181  Centro-Oeste  Urbana      Não
# 151182  Centro-Oeste  Urbana      Sim
# 151184  Centro-Oeste  Urbana      Não
# 151185  Centro-Oeste  Urbana      Não
# 151186  Centro-Oeste  Urbana      Sim
# 151187  Centro-Oeste  Urbana      Não
# 151188  Centro-Oeste  Urbana      Sim
#
# [117601 rows x 3 columns]

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
