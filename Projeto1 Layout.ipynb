# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# # Felippe Teracini
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %%
# Observar a relacao tv-internet ao longo dos 3 anos nas zonas rurais e urbanas das regioes brasileiras

# ?? Observar apenas a partir de alguma renda para distinguir entre quem pode adquirir tv por assinatura
# // Aprender como descobrir a menor renda de alguem que tem tv por assinatura

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Felippe\Documents\Insper\Semestre 2\Ciencia dos Dados\Projeto 1\Projeto-1-CD

# %%
#Se usar o arquivo descompactado
#pd.read_csv('DOM2015.csv',sep=',')

#Se usar o arquivo compactado como está no dropbox púbico
dados2015 = pd.read_csv('DOM2015csv.zip', compression='zip', header=0, sep=',', quotechar='"')

# %%
# Divisão por regiões do Brasil
dados2015.loc[(dados2015.UF <= 17),"Região"] = "Norte"
dados2015.loc[(dados2015.UF > 17) | (dados2015.UF <= 29),"Região"] = "Nordeste"
dados2015.loc[(dados2015.UF > 29) | (dados2015.UF <= 35),"Região"] = "Sudeste"
dados2015.loc[(dados2015.UF > 35) | (dados2015.UF <= 43),"Região"] = "Sul"
dados2015.loc[(dados2015.UF > 43),"Região"] = "Centro-Oeste"

# Divisão por disponibilidade de internet no domicílio
dados2015.loc[(dados2015.V02322 == 2), "Internet"] = "Sim"
dados2015.loc[(dados2015.V02322 == 4), "Internet"] = "Não"
dados2015 = dados2015[pd.notnull(dados2015["V02322"])]

# Divisão por disponibilidade de tv no domicílio
# // Tv por assinatura
dados2015.loc[(dados2015.V02272 == 1), "TvAss"] = "Sim"
dados2015.loc[(dados2015.V02272 == 3), "TvAss"] = "Não"
dados2015 = dados2015[pd.notnull(dados2015["V02272"])]
# // Tv digital aberta !! REMOVER OS NAN
dados2015.loc[(dados2015.V02273 == 1), "TvDigAb"] = "Sim"
dados2015.loc[(dados2015.V02273 == 3), "TvDigAb"] = "Não"
dados2015 = dados2015[pd.notnull(dados2015["V02273"])]
# // Tv aberta antena
dados2015.loc[(dados2015.V02274 == 1), "TvAntAb"] = "Sim"
dados2015.loc[(dados2015.V02274 == 3), "TvAntAb"] = "Não"
dados2015 = dados2015[pd.notnull(dados2015["V02274"])]

# Divisão por zona (Rural ou Urbana)
dados2015.loc[(dados2015.V4105 == 1), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 2), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 3), "Zona"] = "Urbana"
dados2015.loc[(dados2015.V4105 == 4), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 5), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 6), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 7), "Zona"] = "Rural"
dados2015.loc[(dados2015.V4105 == 8), "Zona"] = "Rural"

#Tabela Final
dados2015.loc[:,["Região", "Zona", "Internet", "TvAss", "TvDigAb", "TvAntAb"]]
# Out:
#               Região    Zona Internet TvAss TvDigAb TvAntAb
# 0                Sul  Urbana      Não   Não     Sim     Não
# 3                Sul  Urbana      Sim   Não     Sim     Não
# 5                Sul  Urbana      Sim   Não     Sim     Sim
# 6                Sul  Urbana      Não   Não     Sim     Não
# 7                Sul  Urbana      Não   Não     Sim     Não
# 8                Sul  Urbana      Sim   Não     Sim     Não
# 10               Sul  Urbana      Sim   Sim     Sim     Não
# 11               Sul  Urbana      Sim   Não     Sim     Sim
# 13               Sul  Urbana      Sim   Não     Sim     Sim
# 15               Sul  Urbana      Sim   Não     Sim     Não
# 16               Sul  Urbana      Não   Não     Não     Sim
# 17               Sul  Urbana      Sim   Não     NaN     Não
# 18               Sul  Urbana      Sim   Sim     Sim     Sim
# 19               Sul  Urbana      Sim   Não     NaN     Não
# 20               Sul  Urbana      Sim   Não     Não     Sim
# ...

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
